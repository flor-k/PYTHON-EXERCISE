# %%
#Confeccionar una clase que administre una agenda personal. Se debe almacenar el nombre de la persona, teléfono y mail
#Debe mostrar un menú con las siguientes opciones:
#1- Carga de un contacto en la agenda.
#2- Listado completo de la agenda.
#3- Consulta ingresando el nombre de la persona.
#4- Modificación de su teléfono y mail.
#5- Finalizar programa.

class Agenda:
        
    def __init__(self):
        self.lista={}
        self.cont=0
        self.menu(self)
            
    def menu(self,cont):
        while self.cont!=5:
            print("1- Carga de un contacto en la agenda.")
            print("2- Listado completo de la agenda.")
            print("3- Consulta ingresando el nombre de la persona.")
            print("4- Modificación de su teléfono y mail.")
            print("5- Finalizar programa.")
            self.cont=int(input("ingrese opcion: "))
            if self.cont==1:
                self.carga()
            elif self.cont==2:
                self.listado()
            elif self.cont==3:
                self.consulta()
            elif self.cont==4:
                self.modificacion()
        
    def carga(self):
        cont1="s"
        while cont1!="n":
            nombre=self.nombre=str(input("ingrese nombre de la persona: "))
            numero=self.telefono=input("ingrese numero de telefono: ")
            mail=self.mail=input("ingrese mail: ")
            self.lista[nombre]=([numero,mail])
            cont1=str(input("desea ingresar otra peronsa? s/n"))
        self.menu(self)
        
    def listado(self):
            print(self.lista)
            self.menu(self)
        
    def consulta(self):
        valor=str(input("ingrese nombre a consultar: "))
        if valor in self.lista:
            print("telefono: ",self.lista[valor][0])
            print("mail: ",self.lista[valor][1])
        self.menu(self)
        
        
    def modificacion(self):
        valor=str(input("ingrese nombre de la persona cuyos datos desea cambiar"))
        if valor in self.lista:
            self.lista[valor][0]=input("ingrese telefono nuevo: ")
            self.lista[valor][1]=input("ingrese mail nuevo: ")
        self.menu(self)
        
agenda=Agenda()
# Out:
# 1- Carga de un contacto en la agenda.
# 2- Listado completo de la agenda.
# 3- Consulta ingresando el nombre de la persona.
# 4- Modificación de su teléfono y mail.
# 5- Finalizar programa.
# ingrese opcion: 1
# ingrese nombre de la persona: flor
# ingrese numero de telefono: 1234
# ingrese mail: mailflor
# desea ingresar otra peronsa? s/ns
# ingrese nombre de la persona: pepe
# ingrese numero de telefono: 3456
# ingrese mail: pepemail
# desea ingresar otra peronsa? s/nn
# 1- Carga de un contacto en la agenda.
# 2- Listado completo de la agenda.
# 3- Consulta ingresando el nombre de la persona.
# 4- Modificación de su teléfono y mail.
# 5- Finalizar programa.
# ingrese opcion: 2
# {'flor': ['1234', 'mailflor'], 'pepe': ['3456', 'pepemail']}
# 1- Carga de un contacto en la agenda.
# 2- Listado completo de la agenda.
# 3- Consulta ingresando el nombre de la persona.
# 4- Modificación de su teléfono y mail.
# 5- Finalizar programa.
# ingrese opcion: 3
# ingrese nombre a consultar: pepe
# ...
